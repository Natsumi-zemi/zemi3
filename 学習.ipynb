# %% [markdown]
# <a href="https://colab.research.google.com/github/Natsumi-zemi/zemi3/blob/master/%E5%AD%A6%E7%BF%92.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
sys.path.append('/content/drive/My Drive/gazobunrui/My_module')

import ic_module as ic

import importlib
importlib.reload(ic)

# 関数実行
ic.Learning(tsnum=30, nb_epoch=50, batch_size=8, learn_schedule=0.9)
# Out:
# >> 学習サンプル数 :  (405, 32, 32, 3)
# >> 学習開始
# Epoch 1/50
# 39/40 [============================>.] - ETA: 0s - loss: 1.1303 - accuracy: 0.3526
# Epoch 00001: val_loss improved from inf to 1.10021, saving model to best.hdf5
# 40/40 [==============================] - 3s 68ms/step - loss: 1.1300 - accuracy: 0.3524 - val_loss: 1.1002 - val_accuracy: 0.3333
# Epoch 2/50
# 39/40 [============================>.] - ETA: 0s - loss: 1.0876 - accuracy: 0.3686
# Epoch 00002: val_loss improved from 1.10021 to 1.08312, saving model to best.hdf5
# 40/40 [==============================] - 3s 64ms/step - loss: 1.0879 - accuracy: 0.3683 - val_loss: 1.0831 - val_accuracy: 0.3444
# Epoch 3/50
# 39/40 [============================>.] - ETA: 0s - loss: 1.0489 - accuracy: 0.3942
# Epoch 00003: val_loss improved from 1.08312 to 0.94204, saving model to best.hdf5
# 40/40 [==============================] - 3s 63ms/step - loss: 1.0537 - accuracy: 0.3937 - val_loss: 0.9420 - val_accuracy: 0.5111
# Epoch 4/50
# ...
